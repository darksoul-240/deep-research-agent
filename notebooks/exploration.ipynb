# %%
import os
from dotenv import load_dotenv
from groq import Groq

load_dotenv()
client=Groq(api_key=os.environ.get("GROQ_API_KEY"))
response=client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role":"user","content":"say hello in one sentence"}]
)
print(response.choices[0].message.content)
# Out:
# Hello, it's nice to meet you and I'm here to help with any questions or topics you'd like to discuss.

# %%
""" from duckduckgo_search import DDGS

with DDGS() as ddgs:
    results=list(ddgs.text("ReAct prompting LLM agents", max_results=3))
    for r in results:
        print(r['title'],"-",r['href']) """
from duckduckgo_search import DDGS

try:
    with DDGS(headers={"User-Agent": "Mozilla/5.0"}, timeout=10) as ddgs:
        # Using backend='html' or 'lite' sometimes bypasses blocks
        results = list(ddgs.text("ReAct prompting LLM agents", max_results=3, backend="html"))
        
        if not results:
            print("No results returned. We might be temporarily blocked by DuckDuckGo.")
        else:
            for r in results:
                print(r.get('title', 'No Title'), "-", r.get('href', 'No URL'))
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# C:\Users\Ibrahim\AppData\Local\Temp\ipykernel_16432\2062520593.py:10: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS(headers={"User-Agent": "Mozilla/5.0"}, timeout=10) as ddgs:
# ReAct Prompting | Prompt Engineering Guide - https://www.promptingguide.ai/techniques/react
# Agent 101: Create ReACT Agent From Scratch - Medium - https://medium.com/@ketangangal98/agent-101-create-react-agent-from-scratch-6da28817ffea
# Implementing the ReAct LLM Agent pattern the hard way and the … - https://jschrier.github.io/blog/2024/01/13/Implementing-the-ReAct-LLM-Agent-pattern-the-hard-way-and-the-easy-way.html

# %%
import trafilatura

url="https://en.wikipedia.org/wiki/Retrieval-augmented_generation"
downloaded=trafilatura.fetch_url(url)
text=trafilatura.extract(downloaded)
print(text[:500])
# Out:
# Retrieval-augmented generation
# Retrieval-augmented generation (RAG) is a technique that enables large language models (LLMs) to retrieve and incorporate new information from external data sources.[1] With RAG, LLMs first refer to a specified set of documents, then respond to user queries. These documents supplement information from the LLM's pre-existing training data.[2] This allows LLMs to use domain-specific and/or updated information that is not available in the training data.[2] For example
